# %%
import gzip, json, os
import pandas as pd
from freeplot.utils import export_pickle

# %%
path = "../RecSets/Amazon2023/Office/"
inter_file = "Office_Products.jsonl.gz" # file of review data
meta_file = "meta_Office_Products.jsonl.gz" # file of meta data
dataset = "Amazon2023_Office"

inter_keys = ['user_id', 'asin', 'rating', 'timestamp', 'parent_asin']
inter_cols = ['user_id:token', 'item_id:token', 'rating:float', 'timestamp:float', 'parent_asin:token']
assert len(inter_keys) == len(inter_cols)

meta_keys = ['parent_asin', 'title', 'features', 'description', 'price', 'images', 'videos', 'details']
meta_cols = ['item_id:token', 'parent_asin:token', 'title:token', 'features:token', 'description:token', 'price:float', 'images:token', 'videos:token', 'details:token']
assert len(meta_keys) == len(meta_cols) - 1

# %%
def open_and_read(path, file_):
    data = []
    for line in gzip.open(os.path.join(path, file_)):
        data.append(json.loads(line.strip()))
    return data

# %%
raw_inter = open_and_read(path, inter_file)
raw_inter[0]
# Out:
# {'rating': 5.0,
#  'title': 'Pretty & I love it!',
#  'text': 'Lovely ink. Writes well. The right amount of wet/dry. Currently using it in both a platinum curidas (f) & a pelican twist (m) & it writes well in both.  Beautiful color & flows nicely. It has not clogged up my nibs.',
#  'images': [],
#  'asin': 'B01AHHL4X2',
#  'parent_asin': 'B01MZ3SD2X',
#  'user_id': 'AFKZENTNBQ7A7V7UXW5JJI6UGRYQ',
#  'timestamp': 1677939345945,
#  'helpful_vote': 0,
#  'verified_purchase': True}

# %%
raw_meta = open_and_read(path, meta_file)
raw_meta[0]
# Out:
# {'main_category': 'Office Products',
#  'title': 'Alliance Rubber 07706 Non-Latex Brites File Bands, Colored Elastic Bands, 1.5 oz Pic Pac Dispenser (Assorted Bright Colors and Sizes)',
#  'average_rating': 4.5,
#  'rating_number': 665,
#  'features': ['REUSABLE: These colored rubber bands are stretchable and reusable meaning they can be repurposed for a wide range of different projects and jobs.',
#   'EASY STRETCH BANDS: With their easy stretch design, these non-latex rubber bands are easy to manipulate to secure files and paperwork. This can help in reducing symptoms related to carpal tunnel syndrome from repetitive strain.',
#   'THREE BRITE SHADES: This Pic Pac dispenser contains rubber bands in a variety of bright colors and sizes, making identification and filing quick and easy.',
#   'FILE ORGANIZATION: File rubber bands are a great tool for businesses and the home office, helping you keep your paperwork, folders, files, and print-outs color-coded and organized.',
#   'NON-LATEX RUBBER: These non-latex rubber bands are great for latex-free environments, including schools, businesses and in the home.'],
#  'description': ["Alliance Rubber Brites File Bands are durable, reusable, multipurpose colored elastics designed to make your life easier and allow you to work quicker. Made of non-latex rubber, they are great for use in schools, offices, and homes that are latex-free.  These bands come in a variety of bright shades and sizes in a convenient dispenser for quick and simple file organization. They are easy to stretch and spring back to create a secure and tight fit over a variety of items around the home or office. Brites File Bands can help you organize your office, kitchen, garage, classroom, and craft room. These colored rubber bands are freezer and microwave safe, making them great for creating a tight seal on food storage in the fridge or freezer, and keeping your microwave clean by securing covers or lids when cooking or re-heating.  Colored elastic bands are also a great tool for the DIY-er. Whether you're creating a photo collage, amazing rubber band jewelry, tie-dye clothing with the family, or upgrading old vases and glassware with elastics and spray paint, the options are endless."],
#  'price': 2.68,
#  'images': [{'thumb': 'https://m.media-amazon.com/images/I/51ON9HgdplL._AC_US40_.jpg',
#    'large': 'https://m.media-amazon.com/images/I/51ON9HgdplL._AC_.jpg',
#    'variant': 'MAIN',
#    'hi_res': 'https://m.media-amazon.com/images/I/81-bwFg+7aL._AC_SL1500_.jpg'},
#   {'thumb': 'https://m.media-amazon.com/images/I/51zsnyhi0DL._AC_US40_.jpg',
#    'large': 'https://m.media-amazon.com/images/I/51zsnyhi0DL._AC_.jpg',
#    'variant': 'PT01',
#    'hi_res': 'https://m.media-amazon.com/images/I/81lBsdQDOXL._AC_SL1500_.jpg'},
#   {'thumb': 'https://m.media-amazon.com/images/I/51-frYg4CzL._AC_US40_.jpg',
#    'large': 'https://m.media-amazon.com/images/I/51-frYg4CzL._AC_.jpg',
#    'variant': 'PT02',
#    'hi_res': 'https://m.media-amazon.com/images/I/81Qp7VWmrdL._AC_SL1500_.jpg'},
#   {'thumb': 'https://m.media-amazon.com/images/I/51-8nY1QPbL._AC_US40_.jpg',
#    'large': 'https://m.media-amazon.com/images/I/51-8nY1QPbL._AC_.jpg',
#    'variant': 'PT03',
#    'hi_res': 'https://m.media-amazon.com/images/I/81fyRljrdIL._AC_SL1500_.jpg'},
#   {'thumb': 'https://m.media-amazon.com/images/I/418Z3Lr3HfL._AC_US40_.jpg',
#    'large': 'https://m.media-amazon.com/images/I/418Z3Lr3HfL._AC_.jpg',
#    'variant': 'PT04',
#    'hi_res': 'https://m.media-amazon.com/images/I/81Gikj6pbZL._AC_SL1500_.jpg'},
#   {'thumb': 'https://m.media-amazon.com/images/I/51aWMzqfyRL._AC_US40_.jpg',
#    'large': 'https://m.media-amazon.com/images/I/51aWMzqfyRL._AC_.jpg',
#    'variant': 'PT05',
#    'hi_res': 'https://m.media-amazon.com/images/I/91SodV2F6fL._AC_SL1500_.jpg'},
#   {'thumb': 'https://m.media-amazon.com/images/I/41XYh+W9DYL._AC_US40_.jpg',
#    'large': 'https://m.media-amazon.com/images/I/41XYh+W9DYL._AC_.jpg',
#    'variant': 'PT06',
#    'hi_res': 'https://m.media-amazon.com/images/I/81Q7Z9oqBIL._AC_SL1500_.jpg'},
#   {'thumb': 'https://m.media-amazon.com/images/I/51gD3ePQpHL._AC_US40_.jpg',
#    'large': 'https://m.media-amazon.com/images/I/51gD3ePQpHL._AC_.jpg',
#    'variant': 'PT07',
#    'hi_res': 'https://m.media-amazon.com/images/I/71eApMlbmgL._AC_SL1499_.jpg'}],
#  'videos': [{'title': 'AMUU rubber bands Large 50 Pack 5 colors 8inch',
#    'url': 'https://www.amazon.com/vdp/0fb871b3105d47d89a5a40226cd7b7ea?ref=dp_vse_rvc_0',
#    'user_id': ''},
#   {'title': 'What do you look for in a bag of rubber bands?',
#    'url': 'https://www.amazon.com/vdp/0f61b579cc5f482b8bc2bb7713744c24?ref=dp_vse_rvc_1',
#    'user_id': '/shop/craigobligacionwilson'},
#   {'title': 'Pack of rubber Bands',
#    'url': 'https://www.amazon.com/vdp/04de0a5703734f1b9dded57a43d917db?ref=dp_vse_rvc_2',
#    'user_id': '/shop/superweapons'},
#   {'title': 'Alliance Rubber 07800 Bandas de archivo Brites sin látex, bandas elásticas de colores, 50 unidades',
#    'url': 'https://www.amazon.com/vdp/bfa6c89dfd094f67ad6f5d0803788183?ref=dp_vse_rvc_3',
#    'user_id': ''},
#   {'title': 'Better than clips! #drawing&sketching',
#    'url': 'https://www.amazon.com/vdp/0e2e8957364545948adced896033f0f9?ref=dp_vse_rvc_4',
#    'user_id': '/shop/paulheaston'},
#   {'title': 'Reviving a Houseplant With a Plastic Bag',
#    'url': 'https://www.amazon.com/vdp/00db0ffbbdbe49468fb175c6c0cecdef?ref=dp_vse_rvc_5',
#    'user_id': '/shop/influencer-f419fd51'},
#   {'title': 'Never Expected Rubberbands To Be So Nice! QUICK Overview',
#    'url': 'https://www.amazon.com/vdp/07364da5821d4aeb9173acc7e588919b?ref=dp_vse_rvc_6',
#    'user_id': '/shop/theptcman'}],
#  'store': 'Alliance',
#  'categories': ['Office Products',
#   'Office & School Supplies',
#   'Tape, Adhesives & Fasteners',
#   'Rubber Bands'],
#  'details': {'Manufacturer': 'Alliance Rubber Company Inc.',
#   'Brand': 'Alliance',
#   'Item Weight': '2 ounces',
#   'Product Dimensions': '4.5 x 3 x 1.31 inches',
#   'Item model number': '7706',
#   'Is Discontinued By Manufacturer': 'No',
#   'Color': 'Blue/Orange/Yellow/Lime/Purple/Pink',
#   'Material Type': 'Other',
#   'Number of Items': '1',
#   'Size': 'Assorted Sizes',
#   'Manufacturer Part Number': '7706',
#   'Best Sellers Rank': {'Office Products': 10556, 'Rubber Bands': 55},
#   'Domestic Shipping': 'Item can be shipped within U.S.',
#   'International Shipping': 'This item can be shipped to select countries outside of the U.S.  Learn More',
#   'Date First Available': 'April 4, 2009',
#   'Material': 'Other',
#   'Unit Count': '6.0 Count'},
#  'parent_asin': 'B001S28Q4Q',
#  'bought_together': None}

# %%
# make interaction dataframe 

inters = []

for interaction in raw_inter:
    inters.append(
        [interaction[key] for key in inter_keys]
    )

inter_df = pd.DataFrame(
    inters, columns=inter_cols
)

inter_df
# Out:
#                          user_id:token item_id:token  rating:float  \
# 0         AFKZENTNBQ7A7V7UXW5JJI6UGRYQ    B01AHHL4X2           5.0
# 1         AFKZENTNBQ7A7V7UXW5JJI6UGRYQ    B08L6H23JZ           4.0
# 2         AFKZENTNBQ7A7V7UXW5JJI6UGRYQ    B07JDZ5J46           1.0
# 3         AFKZENTNBQ7A7V7UXW5JJI6UGRYQ    B004MNX7EW           4.0
# 4         AFKZENTNBQ7A7V7UXW5JJI6UGRYQ    B019YLRFFS           3.0
# ...                                ...           ...           ...
# 12845707  AFD7M22ZYOV6HZ6GNVZZQUZH4R4A    B0030INLF0           1.0
# 12845708  AGYDA2QY4QVZB5TR6TUO2PVXWORQ    B07HT28KGD           3.0
# 12845709  AHOKC2PQ4PQ3CPVLLMMIVTM5DJGQ    B0030INLF0           4.0
# 12845710  AFGGT5RI67G5TYXKVFOWBZ4DD2JA    B01GJGC2OK           1.0
# 12845711  AEMUARCPFEENKWQD6DWHTTEUT6SQ    B00006IAO9           5.0
#
#           timestamp:float parent_asin:token
# 0           1677939345945        B01MZ3SD2X
# 1           1677939160682        B08L6H23JZ
# 2           1660188831933        B07JDZ5J46
# 3           1659806066713        B07BR2PBJN
# 4           1659799390978        B097SFY5ZS
# ...                   ...               ...
# 12845707    1447080556000        B0030INLF0
# 12845708    1617820460972        B07HT28KGD
# 12845709    1339179148000        B0030INLF0
# 12845710    1677560507495        B0C4FWH575
# 12845711    1357069137000        B00006IAO9
#
# [12845712 rows x 5 columns]

# %%
# make item dataframe

meta_data = dict()

for item in raw_meta:
    meta_data[item['parent_asin']] = item

items = []

pairs = set(tuple(pair) for pair in inter_df[['item_id:token', 'parent_asin:token']].values.tolist())
for (item_id, parent_id) in pairs:
    items.append(
        [
            item_id, 
            *[meta_data[parent_id][key] for key in meta_keys]
        ]
    )

item_df = pd.DataFrame(
    items,
    columns=meta_cols
)

item_df
# Out:
#        item_id:token parent_asin:token  \
# 0         B008EMXABM        B008EMXABM
# 1         B0050BK7E8        B07C3D2CH8
# 2         B09225DH2W        B09223GK8M
# 3         B07FT76RW5        B07H3LTD3W
# 4         B07FFVPDTJ        B07FFVPDTJ
# ...              ...               ...
# 906044    B07Z4TH84R        B07Z4TH84R
# 906045    B0937FF515        B0937FF515
# 906046    B0773HZBGR        B077NDWJ7D
# 906047    B00D6BC7R4        B00D6BC7R4
# 906048    B00TEGEN9U        B00TEGEN9U
#
#                                            features:token  \
# 0       [Chrome plated metal keychain, Double-sided 3D...
# 1       [Staples 160 - 220 sheets, Made from very stro...
# 2       [PREMIUM MATERIALS: Creative design, elegant a...
# 3       [Package includes 24 cards and 24 white envelo...
# 4       [Included:1 Pack DR730 DR 730 DR-730 Drum Unit...
# ...                                                   ...
# 906044  [★【 Strong Viscosity】- Through new NanoTechnol...
# 906045                                                 []
# 906046  [Set contains 20 x Zebra Sarasa Clip 0.3 Retra...
# 906047  [Soft, black lizard-like cover with twin-wire ...
# 906048  [Introducing Our Delightful Set Of 10 Elephant...
#
#                                         description:token price:float  \
# 0       [This beautiful keychain is chrome plated and ...        None
# 1       [Rapid's Heavy Duty staples are made using ver...        9.87
# 2                                                      []       10.99
# 3       [Celebrate the season and stay in touch with c...        None
# 4                                                      []        None
# ...                                                   ...         ...
# 906044  [Feature of this nano magic tape:, 1. Nano-pu ...        None
# 906045                                                 []        None
# 906046  [Zebra Sarasa Clip 0.3 Retractable Gel Ink Pen...       32.23
# 906047  [Daily Planner, 11" x 8-1/2". Soft, black liza...        None
# 906048  [* There is Nothing Cuter Than a Baby Elephant...        14.5
#
#                                              images:token  \
# 0       [{'thumb': 'https://m.media-amazon.com/images/...
# 1       [{'thumb': 'https://m.media-amazon.com/images/...
# 2       [{'thumb': 'https://m.media-amazon.com/images/...
# 3       [{'thumb': 'https://m.media-amazon.com/images/...
# 4       [{'thumb': 'https://m.media-amazon.com/images/...
# ...                                                   ...
# 906044  [{'thumb': 'https://m.media-amazon.com/images/...
# 906045  [{'thumb': 'https://m.media-amazon.com/images/...
# 906046  [{'thumb': 'https://m.media-amazon.com/images/...
# 906047  [{'thumb': 'https://m.media-amazon.com/images/...
# 906048  [{'thumb': 'https://m.media-amazon.com/images/...
#
#                                              videos:token  \
# 0                                                      []
# 1                                                      []
# 2       [{'title': 'KLIONGO Pen Holder', 'url': 'https...
# 3                                                      []
# 4       [{'title': 'Aztech Compatible Drum Unit Replac...
# ...                                                   ...
# 906044                                                 []
# 906045  [{'title': 'HASFINE Retractable Badge Holder R...
# 906046  [{'title': 'Pentel EnerGel RTX Medium point pe...
# 906047                                                 []
# 906048                                                 []
#
#                                             details:token
# 0       {'Manufacturer': 'Nothing Specific, Inc.', 'Br...
# 1       {'Manufacturer': 'Esselte Corporation', 'Brand...
# 2       {'Specific Uses For Product': 'Cloth,Pen Holde...
# 3       {'Product Dimensions': '5.13 x 1.75 x 9.5 inch...
# 4       {'Manufacturer': 'Brother', 'Brand': 'Aztech',...
# ...                                                   ...
# 906044  {'Manufacturer': 'Ddct', 'Brand': 'Ddct', 'Ite...
# 906045  {'Brand': 'BHROSE', 'Item Weight': '0.317 ounc...
# 906046  {'Manufacturer': 'Stationery JP', 'Brand': 'St...
# 906047  {'Manufacturer': 'REDIFORM OFFICE PRODUCTS', '...
# 906048  {'Product Dimensions': '5.5 x 4.25 x 0.1 inche...
#
# [906049 rows x 8 columns]

# %%
inter_df.to_csv(os.path.join(path, f"{dataset}.inter"), index=False, sep='\t')
item_df.to_csv(os.path.join(path, f"{dataset}.item"), index=False, sep='\t')
